# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.chunk import RegexpParser

# Download required NLTK data
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('averaged_perceptron_tagger_eng', quiet=True)

# Sample sentence
sentence = "The quick brown fox jumps over the lazy dog."

# Tokenization
words = word_tokenize(sentence)

# POS Tagging
pos_tags = nltk.pos_tag(words)

# Noun Phrase Chunking
grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>}
"""

chunk_parser = RegexpParser(grammar)

# Perform chunking
tree = chunk_parser.parse(pos_tags)

print("Words:")
print(words)

print("\nPOS Tags:")
print(pos_tags)

print("\nChunked Tree:")
print(tree)

print("\nParsing and Chunking setup completed!")
# Out:
# Words:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.']
#
# POS Tags:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('.', '.')]
#
# Chunked Tree:
# (S
#   (NP The/DT quick/JJ brown/NN)
#   (NP fox/NN)
#   jumps/VBZ
#   over/IN
#   (NP the/DT lazy/JJ dog/NN)
#   ./.)
#
# Parsing and Chunking setup completed!

# %%
sentence = "Ayush is developing an intelligent chatbot using Python."

# ---------- RegEx Chunking ----------
print("========== REGEX CHUNKING ==========")

words = word_tokenize(sentence)
pos_tags = nltk.pos_tag(words)

# Grammar for Noun Phrase (NP)
grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
"""

chunk_parser = RegexpParser(grammar)
chunk_tree = chunk_parser.parse(pos_tags)

print("\nPOS Tagged Sentence:")
print(pos_tags)

print("\nChunking Result:")
chunk_tree.pretty_print()


# ---------- spaCy Parsing ----------
print("\n========== SPACY DEPENDENCY PARSING ==========")

doc = nlp(sentence)

print("\nWord\tPOS\tDependency\tHead")
print("-" * 45)

for token in doc:
    print(f"{token.text}\t{token.pos_}\t{token.dep_}\t\t{token.head.text}")
# Out:
# ========== REGEX CHUNKING ==========
#
# POS Tagged Sentence:
# [('Ayush', 'NNP'), ('is', 'VBZ'), ('developing', 'VBG'), ('an', 'DT'), ('intelligent', 'NN'), ('chatbot', 'NN'), ('using', 'VBG'), ('Python', 'NNP'), ('.', '.')]
#
# Chunking Result:
#                                         S
#    _____________________________________|_________________________________________
#   |          |            |      |      NP                NP                      NP
#   |          |            |      |      |        _________|____________           |
# is/VBZ developing/VBG using/VBG ./. Ayush/NNP an/DT intelligent/NN chatbot/NN Python/NNP
#
#
# ========== SPACY DEPENDENCY PARSING ==========
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 27
#      24 # ---------- spaCy Parsing ----------
#      25 print("\n========== SPACY DEPENDENCY PARSING ==========")
# ---> 27 doc = nlp(sentence)
#      29 print("\nWord\tPOS\tDependency\tHead")
#      30 print("-" * 45)
#
# NameError: name 'nlp' is not defined
