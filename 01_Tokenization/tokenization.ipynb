# %%
# !pip install nltk spacy
# Out:
# Requirement already satisfied: nltk in c:\users\at232\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: spacy in c:\users\at232\anaconda3\lib\site-packages (3.8.16)
# Requirement already satisfied: click in c:\users\at232\anaconda3\lib\site-packages (from nltk) (8.5.0)
# Requirement already satisfied: joblib in c:\users\at232\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\at232\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\at232\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\at232\anaconda3\lib\site-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\at232\anaconda3\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\at232\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\at232\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\at232\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\at232\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\at232\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\at232\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\at232\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\at232\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in c:\users\at232\anaconda3\lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\users\at232\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\at232\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (5.2.1)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\at232\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.27.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\at232\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: anyio in c:\users\at232\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\at232\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\at232\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\at232\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.14.0)

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# Download required data
nltk.download("punkt", quiet=True)
nltk.download("punkt_tab", quiet=True)

text = "Hello! My name is Ayush. I am learning NLP."

# Sentence Tokenization
sentences = sent_tokenize(text)

# Word Tokenization
words = word_tokenize(text)

print("NLP libraries loaded successfully!")
print("Sentences:", sentences)
print("Words:", words)
# Out:
# NLP libraries loaded successfully!
# Sentences: ['Hello!', 'My name is Ayush.', 'I am learning NLP.']
# Words: ['Hello', '!', 'My', 'name', 'is', 'Ayush', '.', 'I', 'am', 'learning', 'NLP', '.']
